# %% [markdown]
# # 二值化找到图形边界

# %%
import numpy as np
import cv2

# %%
im = cv2.imread('timg.jpg')
cv2.imshow("im",im)
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
cv2.imshow("gray",imgray)
ret,thresh = cv2.threshold(imgray,127,255,0)
cv2.imshow("thresh",thresh)
image, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
cv2.imshow("image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = np.ones(im.shape[:2])
cv2.imshow("img",img)
img = cv2.drawContours(img,contours,-1,(0,255,0),2)
cv2.imshow("imgF",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
contours
# Out:
# [array([[[  0,   0]],
#
#         [[  0, 799]],
#
#         [[799, 799]],
#
#         [[799,   0]]], dtype=int32), array([[[405,  88]],
#
#         [[406,  87]],
#
#         [[418,  87]],
#
#         ...,
#
#         [[378,  89]],
#
#         [[387,  89]],
#
#         [[388,  88]]], dtype=int32), array([[[290, 585]]], dtype=int32), array([[[285, 585]]], dtype=int32), array([[[287, 584]]], dtype=int32), array([[[279, 581]]], dtype=int32), array([[[277, 580]]], dtype=int32), array([[[279, 578]]], dtype=int32), array([[[275, 578]]], dtype=int32), array([[[269, 573]],
#
#         [[269, 574]],
#
#         [[270, 574]],
#
#         [[271, 575]]], dtype=int32), array([[[271, 572]]], dtype=int32), array([[[269, 570]],
#
#         [[267, 572]],
#
#         [[266, 572]],
#
#         [[267, 572]],
#
#         [[268, 571]],
#
#         [[269, 571]]], dtype=int32), array([[[269, 568]],
#
#         [[270, 568]],
#
#         [[271, 569]],
#
#         [[270, 568]]], dtype=int32), array([[[185, 456]]], dtype=int32), array([[[651, 404]],
#
#         [[651, 408]]], dtype=int32), array([[[649, 400]],
#
#         [[649, 401]]], dtype=int32), array([[[619, 260]],
#
#         [[619, 261]],
#
#         [[618, 262]],
#
#         ...,
#
#         [[623, 265]],
#
#         [[622, 264]],
#
#         [[622, 263]]], dtype=int32), array([[[263, 569]],
#
#         [[264, 568]],
#
#         [[265, 569]],
#
#         [[264, 570]]], dtype=int32), array([[[260, 564]],
#
#         [[261, 563]],
#
#         [[262, 563]],
#
#         [[263, 564]],
#
#         [[263, 566]],
#
#         [[262, 567]],
#
#         [[261, 567]],
#
#         [[260, 566]]], dtype=int32), array([[[262, 561]],
#
#         [[263, 560]],
#
#         [[264, 561]],
#
#         [[264, 562]],
#
#         [[263, 563]],
#
#         [[262, 562]]], dtype=int32), array([[[258, 560]],
#
#         [[259, 560]],
#
#         [[260, 561]],
#
#         [[260, 563]],
#
#         [[259, 564]],
#
#         [[258, 564]],
#
#         [[256, 562]]], dtype=int32), array([[[254, 561]],
#
#         [[255, 560]],
#
#         [[256, 561]],
#
#         [[256, 562]],
#
#         [[255, 563]],
#
#         [[254, 562]]], dtype=int32), array([[[260, 560]],
#
#         [[261, 559]],
#
#         [[262, 559]],
#
#         [[263, 560]],
#
#         [[262, 561]],
#
#         [[261, 561]]], dtype=int32), array([[[253, 560]],
#
#         [[254, 559]],
#
#         [[255, 560]],
#
#         [[254, 561]]], dtype=int32), array([[[252, 558]],
#
#         [[253, 557]],
#
#         [[254, 558]],
#
#         [[254, 559]],
#
#         [[253, 560]],
#
#         [[252, 559]]], dtype=int32), array([[[245, 553]],
#
#         [[246, 552]],
#
#         [[247, 553]],
#
#         [[246, 554]]], dtype=int32), array([[[242, 548]],
#
#         [[243, 547]],
#
#         [[244, 548]],
#
#         [[243, 549]]], dtype=int32), array([[[318, 533]],
#
#         [[327, 533]],
#
#         [[328, 534]],
#
#         [[328, 535]],
#
#         [[327, 536]],
#
#         [[317, 536]],
#
#         [[316, 535]]], dtype=int32), array([[[406, 493]],
#
#         [[415, 493]],
#
#         [[416, 494]],
#
#         [[416, 495]],
#
#         [[415, 496]],
#
#         [[405, 496]],
#
#         [[404, 495]]], dtype=int32), array([[[494, 453]],
#
#         [[503, 453]],
#
#         [[504, 454]],
#
#         [[504, 455]],
#
#         [[503, 456]],
#
#         [[493, 456]],
#
#         [[492, 455]]], dtype=int32), array([[[582, 413]],
#
#         [[591, 413]],
#
#         [[592, 414]],
#
#         [[592, 415]],
#
#         [[591, 416]],
#
#         [[581, 416]],
#
#         [[580, 415]]], dtype=int32), array([[[648, 376]],
#
#         [[649, 375]],
#
#         [[650, 376]],
#
#         [[650, 383]],
#
#         [[649, 384]],
#
#         [[648, 383]]], dtype=int32), array([[[650, 374]],
#
#         [[651, 373]],
#
#         [[652, 374]],
#
#         [[652, 375]],
#
#         [[651, 376]],
#
#         [[650, 375]]], dtype=int32), array([[[617, 256]]], dtype=int32)]

# %%
hierarchy
# Out:
# array([[[-1, -1,  1, -1],
#         [-1, -1,  2,  0],
#         [ 3, -1, -1,  1],
#         [ 4,  2, -1,  1],
#         [ 5,  3, -1,  1],
#         [ 6,  4, -1,  1],
#         [ 7,  5, -1,  1],
#         [ 8,  6, -1,  1],
#         [ 9,  7, -1,  1],
#         [10,  8, -1,  1],
#         [11,  9, -1,  1],
#         [12, 10, -1,  1],
#         [13, 11, -1,  1],
#         [14, 12, -1,  1],
#         [15, 13, -1,  1],
#         [16, 14, -1,  1],
#         [33, 15, 17,  1],
#         [18, -1, -1, 16],
#         [19, 17, -1, 16],
#         [20, 18, -1, 16],
#         [21, 19, -1, 16],
#         [22, 20, -1, 16],
#         [23, 21, -1, 16],
#         [24, 22, -1, 16],
#         [25, 23, -1, 16],
#         [26, 24, -1, 16],
#         [27, 25, -1, 16],
#         [28, 26, -1, 16],
#         [29, 27, -1, 16],
#         [30, 28, -1, 16],
#         [31, 29, -1, 16],
#         [32, 30, -1, 16],
#         [-1, 31, -1, 16],
#         [-1, 16, -1,  1]]], dtype=int32)
